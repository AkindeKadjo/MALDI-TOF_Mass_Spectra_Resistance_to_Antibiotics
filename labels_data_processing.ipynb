# %% [markdown]
# by Akinde Kadjo

# %% [markdown]
# **The goal** here is to get the data into a concise form. Due to its large size (20 GB), the data won't be added to GitHub, but the original data set can be found [here.](https://www.kaggle.com/datasets/drscarlat/driams)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import os
from glob import glob
from tqdm import tqdm
from tqdm.keras import TqdmCallback
import time
from difflib import SequenceMatcher

# %% [markdown]
# # Data Extraction

# %%
id2015 = pd.read_csv('id/2015/2015_clean.csv', low_memory=False)
print(id2015.shape)
id2016 = pd.read_csv('id/2016/2016_clean.csv', low_memory=False)
print(id2016.shape)
id2017 = pd.read_csv('id/2017/2017_clean.csv', low_memory=False)
print(id2017.shape)
id2018 = pd.read_csv('id/2018/2018_clean.csv', low_memory=False)
print(id2018.shape)
# Out:
# (3198, 81)
# (34868, 90)
# (43122, 90)
# (30069, 87)

# %%
# concatenating them
id_df = pd.concat([id2015, id2016, id2017, id2018], ignore_index=True)
id_df.shape
# Out:
# (111257, 92)

# %%
id_df.head(2)
# Out:
#                                    code                       species  \
# 0  74969164-613a-4455-ac8e-5666ee0dfade  MIX!Streptococcus pneumoniae
# 1  e9adf43d-679b-497c-9849-1fa214838dd3    Staphylococcus epidermidis
#
#            laboratory_species Piperacillin-Tazobactam Meropenem Ciprofloxacin  \
# 0                         NaN                     NaN       NaN           NaN
# 1  Staphylococcus epidermidis                       R         R             R
#
#   Cefepime Cotrimoxazole Ceftazidime Amikacin  ...  \
# 0      NaN           NaN         NaN      NaN  ...
# 1        R             S           -        -  ...
#
#   Penicillin_without_meningitis Cefuroxime.1 Ceftazidime-Avibactam  \
# 0                           NaN          NaN                   NaN
# 1                           NaN          NaN                   NaN
#
#   Ceftolozane-Tazobactam Ampicillin-Sulbactam Ceftobiprole  \
# 0                    NaN                  NaN          NaN
# 1                    NaN                  NaN          NaN
#
#   Strepomycin_high_level Isavuconazole Unnamed: 0.1 Unnamed: 0
# 0                    NaN           NaN          NaN        NaN
# 1                    NaN           NaN          NaN        NaN
#
# [2 rows x 92 columns]

# %% [markdown]
# # Data Cleaning

# %%
#replace "-" with np.nan
id_df.replace({'-':np.nan}, inplace = True)
id_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111257 entries, 0 to 111256
# Data columns (total 92 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   code                                           111257 non-null  object
#  1   species                                        111257 non-null  object
#  2   laboratory_species                             83653 non-null   object
#  3   Piperacillin-Tazobactam                        28802 non-null   object
#  4   Meropenem                                      29791 non-null   object
#  5   Ciprofloxacin                                  30920 non-null   object
#  6   Cefepime                                       28863 non-null   object
#  7   Cotrimoxazole                                  27042 non-null   object
#  8   Ceftazidime                                    17688 non-null   object
#  9   Amikacin                                       17433 non-null   object
#  10  Levofloxacin                                   21015 non-null   object
#  11  Imipenem                                       29698 non-null   object
#  12  Tobramycin                                     18304 non-null   object
#  13  Ceftriaxone                                    26748 non-null   object
#  14  Colistin                                       18383 non-null   object
#  15  Clindamycin                                    11897 non-null   object
#  16  Amoxicillin-Clavulanic acid                    25564 non-null   object
#  17  Amoxicillin                                    629 non-null     object
#  18  Vancomycin                                     15095 non-null   object
#  19  Penicillin                                     13508 non-null   object
#  20  Metronidazole                                  247 non-null     object
#  21  Erythromycin                                   11304 non-null   object
#  22  Tetracycline                                   10262 non-null   object
#  23  Fluconazole                                    685 non-null     object
#  24  Amphotericin B                                 618 non-null     object
#  25  Caspofungin                                    691 non-null     object
#  26  Micafungin                                     682 non-null     object
#  27  Anidulafungin                                  682 non-null     object
#  28  Itraconazole                                   691 non-null     object
#  29  5-Fluorocytosine                               682 non-null     object
#  30  Voriconazole                                   513 non-null     object
#  31  Posaconazole                                   425 non-null     object
#  32  Ampicillin-Amoxicillin                         27032 non-null   object
#  33  Ertapenem                                      14789 non-null   object
#  34  Cefpodoxime                                    6738 non-null    object
#  35  Norfloxacin                                    6128 non-null    object
#  36  Fosfomycin-Trometamol                          6154 non-null    object
#  37  Nitrofurantoin                                 2149 non-null    object
#  38  Linezolid                                      12289 non-null   object
#  39  Teicoplanin                                    7736 non-null    object
#  40  Tigecycline                                    12282 non-null   object
#  41  Daptomycin                                     11411 non-null   object
#  42  Gentamicin                                     10789 non-null   object
#  43  Gentamicin_high_level                          686 non-null     object
#  44  Aztreonam                                      870 non-null     object
#  45  Minocycline                                    74 non-null      object
#  46  Meropenem_without_meningitis                   142 non-null     object
#  47  Meropenem_with_meningitis                      210 non-null     object
#  48  Chloramphenicol                                203 non-null     object
#  49  Quinolones                                     211 non-null     object
#  50  Clarithromycin                                 313 non-null     object
#  51  Cefuroxime                                     10730 non-null   object
#  52  Oxacillin                                      11150 non-null   object
#  53  Cefazolin                                      10181 non-null   object
#  54  Rifampicin                                     11000 non-null   object
#  55  Fusidic acid                                   10881 non-null   object
#  56  Streptomycin                                   0 non-null       float64
#  57  Rifampicin_1mg-l                               10 non-null      object
#  58  Isoniazid_.1mg-l                               0 non-null       float64
#  59  Pyrazinamide                                   0 non-null       float64
#  60  Ethambutol_5mg-l                               0 non-null       float64
#  61  Azithromycin                                   95 non-null      object
#  62  Cefixime                                       74 non-null      object
#  63  Moxifloxacin                                   414 non-null     object
#  64  Penicillin_with_other_infections               292 non-null     object
#  65  Penicillin_with_meningitis                     292 non-null     object
#  66  Penicillin_with_pneumonia                      293 non-null     object
#  67  Mupirocin                                      3818 non-null    object
#  68  Aminoglycosides                                124 non-null     object
#  69  Meropenem_with_pneumonia                       70 non-null      object
#  70  Amoxicillin-Clavulanic acid_uncomplicated_HWI  80 non-null      object
#  71  Fosfomycin                                     81 non-null      object
#  72  Ticarcillin-Clavulan acid                      5 non-null       object
#  73  Penicillin_without_endokarditis                325 non-null     object
#  74  Penicillin_with_endokarditis                   330 non-null     object
#  75  Doxycycline                                    105 non-null     object
#  76  Cefoxitin_screen                               52 non-null      object
#  77  Isoniazid_.4mg-l                               0 non-null       float64
#  78  Bacitracin                                     4 non-null       object
#  79  Vancomycin_GRD                                 12 non-null      object
#  80  Teicoplanin_GRD                                12 non-null      object
#  81  Ceftarolin                                     37 non-null      object
#  82  Penicillin_without_meningitis                  4 non-null       object
#  83  Cefuroxime.1                                   5 non-null       object
#  84  Ceftazidime-Avibactam                          77 non-null      object
#  85  Ceftolozane-Tazobactam                         107 non-null     object
#  86  Ampicillin-Sulbactam                           14 non-null      object
#  87  Ceftobiprole                                   62 non-null      object
#  88  Strepomycin_high_level                         4 non-null       object
#  89  Isavuconazole                                  5 non-null       object
#  90  Unnamed: 0.1                                   30069 non-null   float64
#  91  Unnamed: 0                                     30069 non-null   float64
# dtypes: float64(7), object(85)
# memory usage: 78.1+ MB

# %%
#drop columns with all missing values (0 non-null)
id_df.dropna(axis = 1, how = 'all', inplace = True)
#drop the non-needed columns
id_df.drop(columns =['laboratory_species', 'Unnamed: 0.1', 'Unnamed: 0' ], 
           inplace = True)
id_df.shape
# Out:
# (111257, 84)

# %%
#overview of entered values
x = id_df.drop(columns =['code', 'species'])
x.apply(pd.Series.value_counts)
# Out:
#                   Piperacillin-Tazobactam  Meropenem  Ciprofloxacin  Cefepime  \
# I                                     403      314.0            711       960
# I(1), S(1)                             36       52.0             77        53
# R                                    6143     4831.0           6751      5558
# R(1), I(1)                             19       32.0             38        92
# R(1), I(1), S(1)                        1        NaN              7         2
# R(1), S(1)                            344      170.0            247       234
# R(2)                                    2        2.0              4         2
# S                                   21852    24386.0          23081     21958
# S(2)                                    2        4.0              4         4
#
#                   Cotrimoxazole  Ceftazidime  Amikacin  Levofloxacin  \
# I                          27.0        567.0     759.0         404.0
# I(1), S(1)                 11.0         82.0     175.0          61.0
# R                        4845.0       1888.0     216.0        3569.0
# R(1), I(1)                  NaN         78.0      12.0          48.0
# R(1), I(1), S(1)            NaN          NaN       NaN           4.0
# R(1), S(1)                391.0        132.0      20.0         114.0
# R(2)                        NaN          NaN       NaN           NaN
# S                       21768.0      14937.0   16247.0       16811.0
# S(2)                        NaN          4.0       4.0           4.0
#
#                   Imipenem  Tobramycin  ...  Teicoplanin_GRD  Ceftarolin  \
# I                   1160.0        56.0  ...              NaN         NaN
# I(1), S(1)            66.0        11.0  ...              NaN         NaN
# R                   5712.0      1639.0  ...              2.0        10.0
# R(1), I(1)            37.0         7.0  ...              NaN         NaN
# R(1), I(1), S(1)       2.0         3.0  ...              NaN         NaN
# R(1), S(1)           198.0        85.0  ...              NaN         NaN
# R(2)                   NaN         NaN  ...              NaN         NaN
# S                  22519.0     16495.0  ...             10.0        27.0
# S(2)                   4.0         8.0  ...              NaN         NaN
#
#                   Penicillin_without_meningitis  Cefuroxime.1  \
# I                                           NaN           NaN
# I(1), S(1)                                  NaN           NaN
# R                                           NaN           NaN
# R(1), I(1)                                  NaN           2.0
# R(1), I(1), S(1)                            NaN           NaN
# R(1), S(1)                                  NaN           NaN
# R(2)                                        NaN           NaN
# S                                           4.0           3.0
# S(2)                                        NaN           NaN
#
#                   Ceftazidime-Avibactam  Ceftolozane-Tazobactam  \
# I                                   1.0                     NaN
# I(1), S(1)                          NaN                     NaN
# R                                  15.0                    35.0
# R(1), I(1)                          NaN                     NaN
# R(1), I(1), S(1)                    NaN                     NaN
# R(1), S(1)                          5.0                     NaN
# R(2)                                NaN                     NaN
# S                                  56.0                    72.0
# S(2)                                NaN                     NaN
#
#                   Ampicillin-Sulbactam  Ceftobiprole  Strepomycin_high_level  \
# I                                  NaN           NaN                     NaN
# I(1), S(1)                         NaN           NaN                     NaN
# R                                 11.0          38.0                     NaN
# R(1), I(1)                         NaN           NaN                     NaN
# R(1), I(1), S(1)                   NaN           NaN                     NaN
# R(1), S(1)                         NaN           NaN                     NaN
# R(2)                               NaN           NaN                     NaN
# S                                  3.0          24.0                     4.0
# S(2)                               NaN           NaN                     NaN
#
#                   Isavuconazole
# I                           NaN
# I(1), S(1)                  NaN
# R                           1.0
# R(1), I(1)                  NaN
# R(1), I(1), S(1)            NaN
# R(1), S(1)                  NaN
# R(2)                        NaN
# S                           4.0
# S(2)                        NaN
#
# [9 rows x 82 columns]

# %% [markdown]
# ## Correct 'species' column

# %%
#checking for inconcistencies
id_df['species'] = id_df['species'].str.lower()
id_df.sort_values('species', inplace = True, ignore_index = True)
id_df['species'].value_counts()
# Out:
# staphylococcus epidermidis              9387
# escherichia coli                        7320
# staphylococcus aureus                   6994
# pseudomonas aeruginosa                  4852
# gardnerella vaginalis                   4447
#                                         ...
# mix!comamonas kerstersii                   1
# mix!corynebacterium flavescens             1
# mix!corynebacterium freneyi                1
# mix!corynebacterium glucuronolyticum       1
# mix!clostridium hathewayi                  1
# Name: species, Length: 1227, dtype: int64

# %% [markdown]
# There should be about ~800 unique species, the above value of 1227 indicates that there could be mispelling.

# %%
#removing'mix!' prefix
id_df['species'] = id_df['species'].str.replace('mix!','')#({'mix!':''}, inplace = True)
id_df.sort_values('species', inplace = True, ignore_index = True)
id_df['species'].value_counts()
# Out:
# staphylococcus epidermidis     9478
# escherichia coli               7381
# staphylococcus aureus          7065
# pseudomonas aeruginosa         4908
# gardnerella vaginalis          4620
#                                ...
# staphylococcus kloosii            1
# clostridium bartlettii            1
# aureimonas altamirensis           1
# bifidobacterium catenulatum       1
# eubacterium sp[2]                 1
# Name: species, Length: 840, dtype: int64

# %% [markdown]
# We went from 1227 to 840. Now let's take care of slightly misspelled species

# %%
#using sequence matcher to match slightly misspelled species name
(r1a,r1b) = ((id_df['species'][0]),(id_df['species'][10]))
r1 = SequenceMatcher(None, r1a, r1b ).ratio()
print(f'{r1a} and {r1b} have a match ratio of {r1}')
(r2a,r2b) = ((id_df['species'][30]),(id_df['species'][60]))
r2 = SequenceMatcher(None, r2a, r2b ).ratio()
print(f'{r2a} and {r2b} have a match ratio of {r2}')
# Out:
# abiotrophia defectiva and abiotrophia defectiva have a match ratio of 1.0
# achromobacter insolitus and achromobacter piechaudii have a match ratio of 0.6808510638297872

# %%
#setting words as the "same" for words with match ratio higher than 0.9
for i in range(1,len(id_df)):
    (ra,rb) = ((id_df['species'][i-1]),(id_df['species'][i]))
    if SequenceMatcher(None, ra, rb ).ratio()>= 0.9:
        id_df.loc[i,'species'] = id_df['species'][i-1]

id_df['species'].value_counts()
# Out:
# staphylococcus epidermidis     9478
# escherichia coli               7381
# staphylococcus aureus          7065
# pseudomonas aeruginosa         4908
# gardnerella vaginalis          4620
#                                ...
# lactobacillus paraplantarum       1
# clostridium sp                    1
# comamonas aquatica                1
# comamonas terrigena               1
# desulfovibrio desulfuricans       1
# Name: species, Length: 825, dtype: int64

# %% [markdown]
# # Data Saving

# %%
id_df.to_csv('labels.csv.gz', index=False, compression='gzip')
